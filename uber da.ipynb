# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import calendar

# %%
df=pd.read_csv('Uber.csv')
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
# 1155        False       True       True    True   True   False      True
#
# [1156 rows x 7 columns]

# %%
df.isnull().any()
# Out:
# START_DATE*    False
# END_DATE*       True
# CATEGORY*       True
# START*          True
# STOP*           True
# MILES*         False
# PURPOSE*        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# START_DATE*    0
# END_DATE*      0
# CATEGORY*      0
# START*         0
# STOP*          0
# MILES*         0
# PURPOSE*       0
# dtype: int64

# %%
df= df.dropna() ## used to remove all the NaN from the dataset

# %%
df.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*      datetime64[ns]
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
df['START_DATE*']=pd.to_datetime(df['START_DATE*'],format='%m/%d/%Y %H:%M')
df['END_DATE*']=pd.to_datetime(df['END_DATE*'],format='%m/%d/%Y %H:%M')
# Out:
# /var/folders/qj/2g9mkm997674wbp8t673rsjr0000gn/T/ipykernel_2088/264328774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['START_DATE*']=pd.to_datetime(df['START_DATE*'],format='%m/%d/%Y %H:%M')
# /var/folders/qj/2g9mkm997674wbp8t673rsjr0000gn/T/ipykernel_2088/264328774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['END_DATE*']=pd.to_datetime(df['END_DATE*'],format='%m/%d/%Y %H:%M')

# %%
hour = []
day=[]
dayofweek=[]
month=[]
weekday=[]

for x in df['START_DATE*']:
    hour.append(x.hour)
    day.append(x.day)
    dayofweek.append(x.dayofweek)
    month.append(x.month)
    weekday.append(calendar.day_name[dayofweek[-1]])
df['HOUR']=hour
df['DAY']=day
df['DAY OF WEEK']=dayofweek
df['MONTH']=month
df['WEEKDAY']=weekday
# Out:
# /var/folders/qj/2g9mkm997674wbp8t673rsjr0000gn/T/ipykernel_2088/2165446896.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HOUR']=hour
# /var/folders/qj/2g9mkm997674wbp8t673rsjr0000gn/T/ipykernel_2088/2165446896.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DAY']=day
# /var/folders/qj/2g9mkm997674wbp8t673rsjr0000gn/T/ipykernel_2088/2165446896.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY OF WEEK  MONTH  \
# 0      Fort Pierce     5.1   Meal/Entertain    21    1            4      1
# 2      Fort Pierce     4.8  Errand/Supplies    20    2            5      1
# 3      Fort Pierce     4.7          Meeting    17    5            1      1
# 4  West Palm Beach    63.7   Customer Visit    14    6            2      1
# 5  West Palm Beach     4.3   Meal/Entertain    17    6            2      1
#
#      WEEKDAY
# 0     Friday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday
# 5  Wednesday

# %%
df['CATEGORY*'].value_counts()
# Out:
# Business    647
# Personal      6
# Name: CATEGORY*, dtype: int64

# %%
sns.countplot(x='CATEGORY*',data=df,color='black')
# Out:
# <AxesSubplot:xlabel='CATEGORY*', ylabel='count'>

# %%
df['MILES*'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
hours=df['START_DATE*'].dt.hour.value_counts()
hours.plot(kind='bar',color='black',figsize=(10,5))

plt.xlabel('Hours')
plt.ylabel('Frequency')
plt.title('Number of trips vs hour')
# Out:
# Text(0.5, 1.0, 'Number of trips vs hour')

# %%
df['PURPOSE*'].value_counts().plot(kind='bar',color='black',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df['HOUR'],color='black')
plt.show()

# %%
df['WEEKDAY'].value_counts().plot(kind='bar',color='black',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df['DAY'].value_counts().plot(kind='bar',color='black',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df['MONTH'].value_counts().plot(kind='bar',color='black',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df['START*'].value_counts().plot(kind='bar',color='black',figsize=(25,20))
# Out:
# <AxesSubplot:>
